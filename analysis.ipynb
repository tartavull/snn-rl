# %% [markdown]
# We will now reopen the file "simulation.hdf5" and try to plot all the important parameters to try to understand what the network is doing
#
# firstly lets, import all required libs

# %%
# %matplotlib inline
import mpld3 
from mpld3 import plugins, utils
import matplotlib.pyplot as plt
mpld3.enable_notebook()

from brianPlotter import *

# %% [markdown]
# We will firstly plot the neuron voltage. we will get the first 10000 points and look for the max value there, then we will take the next 10000 points and look for the minum, and keep till the end. that way we convert 12,000,000 in 112 which are displayed bellow. You can choose for different "compresion" rates (10,100,1000,10000). If you choose 1 you will be seeing the real data. But remember, when more points are shown more ram is use.

# %%
level = 10000 #try  (1,10,100,1000) 

bp = brianPlotter('simulation.hdf5',permision = "r")
data = bp.getData('voltage',level)

time = range(1,data.shape[0]*level,level)
nrows = data.shape[1]

fig, axes = plt.subplots(ncols=1, nrows=nrows, figsize=(13,nrows*3))
for index in range(4):
    axes[index].plot(time, data[:,index])
plt.xlabel('Time (in seconds)')
plt.ylabel('Membrane potential (in mV)')
plt.title('Membrane potential for neurons')

del bp

# %% [markdown]
# We can indentify some tendency among all neurons, we will now plot the weights to see if there is a correlation between this behaviour and the weights.
#
# Firstly , we will plot excitatory weights which corresponds to the synapses that connects the first layer and the second on.
# Secondly, we plot the inhibitory weights which represents the connection within neurons of the second layer, a neuron can inhibit itself in out model, so there are no weights for the diagonal.

# %%
level = 10000
bp = brianPlotter('simulation.hdf5' ,permision = "r")
weights = bp.getData('excitatory',level)
time = range(1,weights.shape[0]*level,level)

nColWeight = weights.shape[2]
nRows = weights.shape[1]

fig, axes = plt.subplots(ncols=nColWeight,nrows=nRows, sharey=True,sharex = True, figsize=(13,25))
fig.tight_layout()

for index in range(nColWeight*nRows):
    row = index%nRows
    column = index/nRows
    line = weights[:,row,column]
    axes[row,column].plot(time,line)
    plt.ylabel('Synaptic strength (in mV)')
    plt.xlabel('Time (in seconds)')
plt.show()

del bp

# %%
level = 10000
bp = brianPlotter('simulation.hdf5' ,permision = "r")
weights = bp.getData('inhibitory',level)
time = range(1,weights.shape[0]*level,level)

nColWeight = weights.shape[2]
nRows = weights.shape[1]

fig, axes = plt.subplots(ncols=nColWeight,nrows=nRows, sharey=True,sharex = True, figsize=(13,nRows*2))
fig.tight_layout()

for index in range(nColWeight*nRows):
    row = index%nRows
    column = index/nRows
    line = weights[:,row,column]
    axes[row,column].plot(time,line)
    plt.ylabel('Synaptic strength (in mV)')
    plt.xlabel('Time (in seconds)')
plt.show()

del bp

# %% [markdown]
# it's interesting to notice that row 4 and 10, of the excitatory weigths remain constant, that's because then neuron 4 and 10 of the first layer never spikes, because the character all always of in those pixels.
#
# Why inhibitory weights are constant?

# %%
#This used to be an scatter plot of the firings, but we haven't 
#implemented downsampling for sparse arrays so it's not yet available

neuronArray = np.empty(0, dtype=int)
firetimeArray = np.empty(0, dtype=float)
neuronColor = np.random.rand(15)
colors = np.empty(0, dtype=float)

fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'),figsize=(13,4))
for neuron in range(0,4):
    for fire in range(0,spikes[neuron].size):
       neuronArray = np.append(neuronArray, neuron)
       firetimeArray = np.append(firetimeArray,spikes[neuron][fire])
       colors = np.append(colors,neuronColor[neuron])

points = plt.scatter(firetimeArray,neuronArray, s=100, c=colors)
plt.yticks(np.arange(0,4, 1.0))
plt.ylabel("Neuron number")
plt.xlabel("Time(seconds)")
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f7789c3f1e7e> in <module>()
#       9 fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'),figsize=(13,4))
#      10 for neuron in range(0,4):
# ---> 11     for fire in range(0,spikes[neuron].size):
#      12        neuronArray = np.append(neuronArray, neuron)
#      13        firetimeArray = np.append(firetimeArray,spikes[neuron][fire])
#
# NameError: name 'spikes' is not defined
