# %% [markdown]
# We will now reopen the file "simulation.hdf5" and try to plot all the important parameters to try to understand what the network is doing
#
# firstly lets, import all required libs

# %%
import io
from IPython.nbformat import current

def execute_notebook(nbfile):
    
    with io.open(nbfile) as f:
        nb = current.read(f, 'json')
    
    ip = get_ipython()
    
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)
        
execute_notebook("commonFurtherFormulas.ipynb")
# Out:
# Sat Jan 17 17:51:27 2015

# %% [markdown]
# ## Training

# %% [markdown]
# We will firstly plot the neuron voltage during training.  The training period was 2000ms.  The voltage was downsampled 10 times for the graph below so only a portion of the origional data is provided but the general trend of training is observable.  Each input letter is presented 3 times and the appropriate neuron is trained on it.  The spiking over time of each neuron based on the input data is seen.

# %% [markdown]
# ## Testing

# %% [markdown]
# The 'testVoltage' is the voltage produced when the evaluation test period is run.  Each input letter is presented 3 times as in training and all neurons are given the chance to fire a spike.  The neurons that spiked are seen in the graph.  There is much overlap but some pixels do overlap in the images, tuning and improving the weight training can result in higher performance.  I have the idea that the spike time dependency creates the build up of signal over time which could contribute to streaks of spiking or non spiking but I may be wrong, more inspection could help.
#
# Some statistics on the results are:
#
# +++ Results +++
#
# Spike results: TP:	7 	FP:	21 	TN:	14 	FN:	4
#
# totalSpikeIntervalsTested:	12 	totalCharsPresented:	4
#
# True positives correct percentage (TP/totalSpikeIntervalsTested):	0.5833333333333333333333333333 	(this is the percentage of all true
# positves that were found)
#
# Total correct percentage (TP+TN/(totalSpikeIntervals*totalCharsPresented)):	0.4375

# %%
bp = brianPlotter('simulation.hdf5',permision = "r")

start = .001 #seconds
end = 5
bp.plotLine('voltage',start,end)
bp.plotScatter(start,end) #downsampling not yet implemented for scatter
start = .001 #seconds
end = .0119
bp.plotLine('testVoltage',start,end)
start = .001 #seconds
end = .119
bp.plotTestScatter(start,end) #downsampling not yet implemented for scatter

del bp
# Out:
# voltage has been downsampled 10 times
# (200, 4)
# WARNING: you requested end = 5000.0 seconds but data length is 0.0 seconds
# testVoltage has been downsampled 1 times
