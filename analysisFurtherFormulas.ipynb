# %% [markdown]
# We will now reopen the file "simulation.hdf5" and try to plot all the important parameters to try to understand what the network is doing
#
# firstly lets, import all required libs

# %%
import io
from IPython.nbformat import current

def execute_notebook(nbfile):
    
    with io.open(nbfile) as f:
        nb = current.read(f, 'json')
    
    ip = get_ipython()
    
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)
        
execute_notebook("common.ipynb")
# Out:
# Wed Jan 07 20:53:45 2015

# %% [markdown]
# We will firstly plot the neuron voltage. we will get the first 10000 points and look for the max value there, then we will take the next 10000 points and look for the minum, and keep till the end. that way we convert 1,200,000 in 112 which are displayed bellow. You can choose for different "compresion" rates (10,100,1000,10000). If you choose 1 you will be seeing the real data. But remember, when more points are shown more ram is use.

# %%
bp = brianPlotter('simulation.hdf5',permision = "r")

start = .0001 #seconds
end = .0019
bp.plotLine('voltage',start,end)
bp.plotScatter(start,end) #downsampling not yet implemented for scatter

del bp
# Out:
# voltage has been downsampled 1 times
# (0, 4)
# WARNING: you requested end = 19.0 seconds but data length is 0.0 seconds
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-5ec4e800a656> in <module>()
#       4 end = .0019
#       5 bp.plotLine('voltage',start,end)
# ----> 6 bp.plotScatter(start,end) #downsampling not yet implemented for scatter
#       7
#       8 del bp
#
# <ipython-input-7-035f6245f1e5> in plotScatter(self, start, end)
#      65         spikes = self.getData('spikes',1)
#      66
# ---> 67         start =  self.binary_search(spikes[:,1], start)
#      68         end = self.binary_search(spikes[:,1], end)
#      69
#
# C:\Python27\lib\site-packages\h5py\_hl\dataset.pyc in __getitem__(self, args)
#     423
#     424         # Perform the dataspace selection.
# --> 425         selection = sel.select(self.shape, args, dsid=self.id)
#     426
#     427         if selection.nselect == 0:
#
# C:\Python27\lib\site-packages\h5py\_hl\selections.pyc in select(shape, args, dsid)
#      89
#      90     sel = SimpleSelection(shape)
# ---> 91     sel[args]
#      92     return sel
#      93
#
# C:\Python27\lib\site-packages\h5py\_hl\selections.pyc in __getitem__(self, args)
#     256             return self
#     257
# --> 258         start, count, step, scalar = _handle_simple(self.shape,args)
#     259
#     260         self._id.select_hyperslab(start, count, step)
#
# C:\Python27\lib\site-packages\h5py\_hl\selections.pyc in _handle_simple(shape, args)
#     511         else:
#     512             try:
# --> 513                 x,y,z = _translate_int(int(arg), length)
#     514                 s = True
#     515             except TypeError:
#
# C:\Python27\lib\site-packages\h5py\_hl\selections.pyc in _translate_int(exp, length)
#     531
#     532     if not 0<=exp<length:
# --> 533         raise ValueError("Index (%s) out of range (0-%s)" % (exp, length-1))
#     534
#     535     return exp, 1, 1
#
# ValueError: Index (1) out of range (0--1)

# %% [markdown]
# We can indentify some tendency among all neurons, we will now plot the weights to see if there is a correlation between this behaviour and the weights.
#
# Firstly , we will plot excitatory weights which corresponds to the synapses that connects the first layer and the second on.
# Secondly, we plot the inhibitory weights which represents the connection within neurons of the second layer, a neuron can inhibit itself in out model, so there are no weights for the diagonal.

# %% [markdown]
# it's interesting to notice that row 4 and 10, of the excitatory weigths remain constant, that's because then neuron 4 and 10 of the first layer never fired, because the all character have those pixels off.
